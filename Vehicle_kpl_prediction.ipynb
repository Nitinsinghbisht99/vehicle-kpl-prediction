# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

file_path = "/content/drive/MyDrive/vehicle_data.csv"
df = pd.read_csv(file_path)

print(df.head())  # Display first few rows
# Out:
#    origin  cylinders  displacement horsepower  weight  acceleration  year  \
# 0       1          8         307.0        130    3504          12.0  1970
# 1       1          8         350.0        165    3693          11.5  1970
# 2       1          8         318.0        150    3436          11.0  1970
# 3       1          8         304.0        150    3433          12.0  1970
# 4       1          8         302.0        140    3449          10.5  1970
#
#                         name  Kilometer_per_liter
# 0  chevrolet chevelle malibu             7.652587
# 1          buick skylark 320             6.377156
# 2         plymouth satellite             7.652587
# 3              amc rebel sst             6.802299
# 4                ford torino             7.227443

# %%
df.head()
# Out:
#    origin  cylinders  displacement horsepower  weight  acceleration  year  \
# 0       1          8         307.0        130    3504          12.0  1970
# 1       1          8         350.0        165    3693          11.5  1970
# 2       1          8         318.0        150    3436          11.0  1970
# 3       1          8         304.0        150    3433          12.0  1970
# 4       1          8         302.0        140    3449          10.5  1970
#
#                         name  Kilometer_per_liter
# 0  chevrolet chevelle malibu             7.652587
# 1          buick skylark 320             6.377156
# 2         plymouth satellite             7.652587
# 3              amc rebel sst             6.802299
# 4                ford torino             7.227443

# %%
df.shape
# Out:
# (398, 9)

# %%
## handling null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   origin               398 non-null    int64
#  1   cylinders            398 non-null    int64
#  2   displacement         398 non-null    float64
#  3   horsepower           398 non-null    object
#  4   weight               398 non-null    int64
#  5   acceleration         398 non-null    float64
#  6   year                 398 non-null    int64
#  7   name                 398 non-null    object
#  8   Kilometer_per_liter  398 non-null    float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.isnull().sum()
# Out:
# origin                 0
# cylinders              0
# displacement           0
# horsepower             0
# weight                 0
# acceleration           0
# year                   0
# name                   0
# Kilometer_per_liter    0
# dtype: int64

# %%
## handling duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['origin', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'year', 'name', 'Kilometer_per_liter'],
#       dtype='object')

# %%
for i in df:
  print(df[i].unique())
  print(i)
  print("***************************************")
# Out:
# [1 3 2]
# origin
# ***************************************
# [8 4 6 3 5]
# cylinders
# ***************************************
# [307.  350.  318.  304.  302.  429.  454.  440.  455.  390.  383.  340.
#  400.  113.  198.  199.  200.   97.  110.  107.  104.  121.  360.  140.
#   98.  232.  225.  250.  351.  258.  122.  116.   79.   88.   71.   72.
#   91.   97.5  70.  120.   96.  108.  155.   68.  114.  156.   76.   83.
#   90.  231.  262.  134.  119.  171.  115.  101.  305.   85.  130.  168.
#  111.  260.  151.  146.   80.   78.  105.  131.  163.   89.  267.   86.
#  183.  141.  173.  135.   81.  100.  145.  112.  181.  144. ]
# displacement
# ***************************************
# ['130' '165' '150' '140' '198' '220' '215' '225' '190' '170' '160' '95'
#  '97' '85' '88' '46' '87' '90' '113' '200' '210' '193' '?' '100' '105'
#  '175' '153' '180' '110' '72' '86' '70' '76' '65' '69' '60' '80' '54'
#  '208' '155' '112' '92' '145' '137' '158' '167' '94' '107' '230' '49' '75'
# ...

# %%
df=df[df['horsepower']!='?']

# %%
df['horsepower'] = pd.to_numeric(df['horsepower'])
df.dtypes
# Out:
# <ipython-input-14-3776bf22d5f2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['horsepower'] = pd.to_numeric(df['horsepower'])
# origin                   int64
# cylinders                int64
# displacement           float64
# horsepower               int64
# weight                   int64
# acceleration           float64
# year                     int64
# name                    object
# Kilometer_per_liter    float64
# dtype: object

# %%
df.shape
# Out:
# (392, 9)

# %%
for i in df:
  print(df[i].value_counts())
  print(i)
  print('_________')
# Out:
# origin
# 1    245
# 3     79
# 2     68
# Name: count, dtype: int64
# origin
# _________
# cylinders
# 4    199
# 8    103
# 6     83
# 3      4
# 5      3
# Name: count, dtype: int64
# cylinders
# _________
# displacement
# 97.0     21
# 350.0    18
# 98.0     17
# 318.0    17
# 250.0    17
#          ..
# 104.0     1
# 110.0     1
# 130.0     1
# 111.0     1
# 144.0     1
# Name: count, Length: 81, dtype: int64
# displacement
# _________
# horsepower
# 150    22
# 90     20
# 88     19
# 110    18
# 100    17
#        ..
# 61      1
# 93      1
# 148     1
# 152     1
# 82      1
# Name: count, Length: 93, dtype: int64
# horsepower
# _________
# weight
# 1985    4
# 2130    4
# 2125    3
# 2720    3
# 2945    3
#        ..
# 3102    1
# 3664    1
# 2807    1
# 2660    1
# 2625    1
# Name: count, Length: 346, dtype: int64
# weight
# _________
# acceleration
# 14.5    23
# 15.5    21
# 14.0    16
# 16.0    16
# 13.5    15
#         ..
# 11.1     1
# 12.1     1
# 21.9     1
# ...

# %%
df['origin'].value_counts()
# Out:
# origin
# 1    245
# 3     79
# 2     68
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
sns.countplot(x=df['origin'],data=df)
# Out:
# <Axes: xlabel='origin', ylabel='count'>

# %%
###  origin 1 car have better KPL

# %%
sns.countplot(x=df['cylinders'],data=df)
# Out:
# <Axes: xlabel='cylinders', ylabel='count'>

# %%
df.drop('name',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['origin', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'year', 'Kilometer_per_liter'],
#       dtype='object')

# %%
## car which have 4 cylinder are more better in KPL

# %%
from scipy.stats import shapiro, ks_2samp

stat, p_value = shapiro(df['Kilometer_per_liter'])
print(f"Shapiro-Wilk Test: p-value = {p_value}")

if p_value < 0.05:
    print("Data is NOT normally distributed.")
else:
    print("Data is normally distributed.")
# Out:
# Shapiro-Wilk Test: p-value = 1.0494407063379124e-07
# Data is NOT normally distributed.

# %%
sns.distplot(df['Kilometer_per_liter'])
plt.show()
# Out:
# <ipython-input-26-d71dfd921514>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Kilometer_per_liter'])

# %%
sns.distplot(np.log(df['Kilometer_per_liter']))
plt.show()
# Out:
# <ipython-input-27-d81c2a523b9a>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Kilometer_per_liter']))

# %%
df.head()
# Out:
#    origin  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0       1          8         307.0         130    3504          12.0  1970
# 1       1          8         350.0         165    3693          11.5  1970
# 2       1          8         318.0         150    3436          11.0  1970
# 3       1          8         304.0         150    3433          12.0  1970
# 4       1          8         302.0         140    3449          10.5  1970
#
#    Kilometer_per_liter
# 0             7.652587
# 1             6.377156
# 2             7.652587
# 3             6.802299
# 4             7.227443

# %%
## Handling outliers

df.columns
# Out:
# Index(['origin', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'year', 'Kilometer_per_liter'],
#       dtype='object')

# %%
cat_cols=['origin','cylinders']
int_cols=[ 'displacement', 'horsepower', 'weight',
       'acceleration', 'year', 'Kilometer_per_liter']

# %%
for i in int_cols:
  sns.boxplot(x=df[i])
  plt.title(i)
  plt.show()

# %%
## we can see that horsepower and and acceleration has outliers
## Horsepower  has outliers beyond the max and accelaration has outliers in both the side

# %%
df.describe(percentiles=[0.95,0.96,0.97,0.98,0.99]).T
# Out:
#                      count         mean         std          min          50%  \
# origin               392.0     1.576531    0.805518     1.000000     1.000000
# cylinders            392.0     5.471939    1.705783     3.000000     4.000000
# displacement         392.0   194.411990  104.644004    68.000000   151.000000
# horsepower           392.0   104.469388   38.491160    46.000000    93.500000
# weight               392.0  2977.584184  849.402560  1613.000000  2803.500000
# acceleration         392.0    15.541327    2.758864     8.000000    15.500000
# year                 392.0  1975.979592    3.683737  1970.000000  1976.000000
# Kilometer_per_liter  392.0     9.967885    3.318250     3.826293     9.672019
#
#                              95%          96%         97%          98%  \
# origin                  3.000000     3.000000     3.00000     3.000000
# cylinders               8.000000     8.000000     8.00000     8.000000
# ...

# %%
import numpy as np

df['horsepower'] = np.where(df['horsepower'] > 200, 200, df['horsepower'])
df['acceleration']=np.where(df['acceleration']>21,21,df['acceleration'])
df['acceleration']=np.where(df['acceleration']<9,9,df['acceleration'])

# %%
for i in int_cols:
  sns.boxplot(x=df[i])
  plt.title(i)
  plt.show()

# %%
# corr

# %%
corr = df.corr()
corr
# Out:
#                        origin  cylinders  displacement  horsepower    weight  \
# origin               1.000000  -0.568932     -0.614535   -0.462494 -0.585005
# cylinders           -0.568932   1.000000      0.950823    0.854518  0.897527
# displacement        -0.614535   0.950823      1.000000    0.901088  0.932994
# horsepower          -0.462494   0.854518      0.901088    1.000000  0.875534
# weight              -0.585005   0.897527      0.932994    0.875534  1.000000
# acceleration         0.216752  -0.514420     -0.554577   -0.700252 -0.427118
# year                 0.181528  -0.345647     -0.369855   -0.414745 -0.309120
# Kilometer_per_liter  0.565209  -0.777618     -0.805127   -0.790078 -0.832244
#
#                      acceleration      year  Kilometer_per_liter
# origin                   0.216752  0.181528             0.565209
# cylinders               -0.514420 -0.345647            -0.777618
# displacement            -0.554577 -0.369855            -0.805127
# ...

# %%
plt.figure(figsize=(7,6))
sns.heatmap(corr,annot=True,cmap='RdBu')
plt.show()

# %%
plt.figure(figsize=(7,6))
sns.heatmap(corr[abs(corr)>0.7],annot=True,cmap='RdBu')
plt.show()

# %%
#we can see that cylinders, displacement,horsepower, weight and accelertaion are highly correlated

# %%
df.dtypes  #  every columns are in integer form or float so no encoding
# Out:
# origin                   int64
# cylinders                int64
# displacement           float64
# horsepower               int64
# weight                   int64
# acceleration           float64
# year                     int64
# Kilometer_per_liter    float64
# dtype: object

# %%
## Making  x, y

# %%
x=df.drop(['Kilometer_per_liter'],axis=1)
y=df['Kilometer_per_liter']

print(x.shape)
print(y.shape)
# Out:
# (392, 7)
# (392,)

# %%
## Data distributaion on test and train data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (313, 7)
# (79, 7)
# (313,)
# (79,)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)  # Predict using the test set

# %%
# Evaluate performance on the test set
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error: {mae}")
print(f"Mean Squared Error: {mse}")
print(f"Root Mean Squared Error: {rmse}")
print(f"R^2 Score: {r2}")
# Out:
# Mean Absolute Error: 1.0319280020244923
# Mean Squared Error: 1.9438500609819005
# Root Mean Squared Error: 1.3942202340311594
# R^2 Score: 0.7892946207199969
